# %%
import pandas as pd

# %%
df= pd.read_csv("../Data/Games.csv")
df
# Out:
#               Team             Opp        Date Result H/A  GF  GA  GD  Poss  \
# 0         Gladbach      Leverkusen  2024-08-23      L   H   2   3  -1    43
# 1       Leverkusen        Gladbach  2024-08-23      W   A   3   2   1    57
# 2    Holstein Kiel      Hoffenheim  2024-08-24      L   A   2   3  -1    46
# 3    Werder Bremen        Augsburg  2024-08-24      D   A   2   2   0    54
# 4     Union Berlin        Mainz 05  2024-08-24      D   A   1   1   0    47
# ..             ...             ...         ...    ...  ..  ..  ..  ..   ...
# 411     RB Leipzig      Heidenheim  2025-02-23      D   H   2   2   0    74
# 412  Bayern Munich  Eint Frankfurt  2025-02-23      W   H   4   0   4    63
# 413     Heidenheim      RB Leipzig  2025-02-23      D   A   2   2   0    26
# 414  Bayern Munich       Stuttgart  2025-02-28      W   A   3   1   2    47
# 415      Stuttgart   Bayern Munich  2025-02-28      L   H   1   3  -2    53
#
#               Comp  ...  xAG   xA  G-xG  np:G-xG  A-xAG  npxG/Sh  FKAtt  PSxG  \
# 0    de Bundesliga  ...  0.8  1.1   0.4      0.4   -0.8     0.12      0   2.3
# 1    de Bundesliga  ...  1.2  1.2   0.3      1.3   -1.2     0.07      1   2.3
# 2    de Bundesliga  ...  1.2  0.7   0.3      0.3    0.8     0.11      0   3.8
# 3    de Bundesliga  ...  1.4  1.2   0.6      0.6    0.6     0.13      0   1.5
# 4    de Bundesliga  ...  0.5  0.5   0.4      0.4    0.5     0.04      0   0.8
# ..             ...  ...  ...  ...   ...      ...    ...      ...    ...   ...
# 411  de Bundesliga  ...  0.9  1.3   0.1     -0.1    0.1     0.07      0   1.1
# 412  de Bundesliga  ...  2.6  3.1   0.2      0.2   -0.6     0.21      0   0.3
# 413  de Bundesliga  ...  0.1  0.5   1.2      0.9    0.9     0.02      0   2.6
# 414  de Bundesliga  ...  1.4  0.7   0.8      0.8   -0.4     0.13      2   0.4
# 415  de Bundesliga  ...  0.9  1.5   0.1      0.1    0.1     0.08      0   2.5
#
#      PSxG/SoT  PSxG+/-
# 0        0.14     -0.7
# 1        0.36      0.3
# 2        0.37      0.8
# 3        0.49     -0.5
# 4        0.28     -0.2
# ..        ...      ...
# 411      0.18     -0.9
# 412      0.15      0.3
# 413      0.30      0.6
# 414      0.14     -0.6
# 415      0.31     -0.5
#
# [416 rows x 157 columns]

# %%
df= df.drop(columns=["Comp"])

# %%
df_teams = {tm: df[df["Team"] == tm] for tm in df["Team"].unique()}

# %%
df_opps= {tm: df[df["Opp"] == tm] for tm in df["Opp"].unique()}

# %%
for team in df_teams.keys():
    df_teams[team].to_csv(f"../Data/{team}.csv", index=False)
    df_opps[team].to_csv(f"../Data/vs {team}.csv", index=False)
